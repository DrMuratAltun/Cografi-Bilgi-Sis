# %% [markdown]
# ![What-Is-Geographic-Information-Systems-Featured.jpg](data:image/jpeg;base64,...)

# %%
# !pip install -U Leafmap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 17.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 48.6 MB/s eta 0:00:00
# ...

# %%
# !pip install rasterio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 30.6 MB/s eta 0:00:00
# ...

# %%
# !pip install geopandas

# %%
import leafmap

# %%
m=leafmap.Map()
m.add_basemap('HYBRID')
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
m.to_html('mymap.html')
#downlad file
from google.colab import files
files.download('mymap.html')

# %%
m.add_basemap('SATELLITE')
m
# Out:
# Map(bottom=507.0, center=[-73.62778879339942, 489.56276998794834], controls=(ZoomControl(options=['position', …

# %%
m.add_basemap('TERRAIN')
m
# Out:
# Map(bottom=678.0, center=[42.553080288955826, 603.9901641551247], controls=(ZoomControl(options=['position', '…

# %%
img1 = "https://open.gishub.org/data/images/berkeley.jpg"
img2 = "https://open.gishub.org/data/images/berkeley_sam.jpg"
leafmap.image_comparison(
    img1,
    img2,
    label1="Satellite Image",
    label2="Image Segmentation",
    starting_position=50,
    out_html="image_comparison.html"
)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#https://leafmap.org/notebooks/72_timelapse/#landsat-timelapse
import geopandas as gpd
gdf = gpd.read_file(
    "https://github.com/opengis/leafletmap/raw/master/examples/data/cable_geo.geojson"
)
